# %% [markdown]
# <a href="https://colab.research.google.com/github/hwanjae1997/College-Basketball/blob/main/Yoo_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hwanjae Yoo's Final Individual Case Study**
#
# I chose this dataset because of my interest in basketball. I normally watch more NBA than I do college, but March Madness this year has peaked an interest that Illinois has not experienced since 2004/2005, so I felt this dataset would be interesting to take a look at.

# %% [markdown]
# **Questions of Interest**
#
#
# 1.   What team won the highest number of total games in 2021?
# 2.   Which team improved the most in winning percentage over the course of the  year?
# 3. Which team had the best record in each conference over the course of the past year?
# 5. Is there a correlation with winning and adjusted offensive or defensive efficiency?

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# **Basic Information about the data displayed below.**

# %%
df = pd.read_csv('https://github.com/hwanjae1997/College-Basketball/raw/main/cbb21.csv')

# %%
df.shape
# Out:
# (347, 22)

# %%
num_rows = df.shape[0]
num_col = df.shape[1]
print(num_rows)
print(num_col)
# Out:
# 347
# 22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TEAM     347 non-null    object
#  1   CONF     347 non-null    object
#  2   G        347 non-null    int64
#  3   W        347 non-null    int64
#  4   ADJOE    347 non-null    float64
#  5   ADJDE    347 non-null    float64
#  6   BARTHAG  347 non-null    float64
#  7   EFG_O    347 non-null    float64
#  8   EFG_D    347 non-null    float64
#  9   TOR      347 non-null    float64
#  10  TORD     347 non-null    float64
#  11  ORB      347 non-null    float64
#  12  DRB      347 non-null    float64
#  13  FTR      347 non-null    float64
#  14  FTRD     347 non-null    float64
#  15  2P_O     347 non-null    float64
#  16  2P_D     347 non-null    float64
#  17  3P_O     347 non-null    float64
#  18  3P_D     347 non-null    float64
#  19  ADJ_T    347 non-null    float64
# ...

# %%
df.head(5)
df.tail(5)
# Out:
#                  TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 342    Louisiana Tech  CUSA  27  21  102.7  ...  34.6  29.6   69.6 -1.7   NaN
# 343            Toledo   MAC  29  21  113.3  ...  37.7  29.5   69.1 -2.1   NaN
# 344               UAB  CUSA  27  22  102.5  ...  31.1  32.4   67.5 -2.7   NaN
# 345  Eastern Kentucky   OVC  27  22  101.5  ...  35.8  33.0   75.1 -3.8   NaN
# 346           Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1 -1.1   NaN
#
# [5 rows x 22 columns]

# %%
df.sample(50)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 3                   Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 260               Idaho St.  BSky  19  13   92.3  ...  30.2  36.5   64.6  -8.5   NaN
# 288          Washington St.   P12  27  14  101.1  ...  34.1  31.3   68.0  -4.5   NaN
# 19                 Colorado   P12  30  22  113.7  ...  36.7  33.3   66.3   2.6   5.0
# 186      Florida Gulf Coast  ASun  16  10   92.1  ...  28.9  31.5   71.0  -6.6   NaN
# 12              Florida St.   ACC  22  16  117.8  ...  39.0  33.3   70.4   2.5   4.0
# 244                    Utah   P12  25  12  110.8  ...  35.5  36.0   67.6  -3.9   NaN
# 168              Quinnipiac  MAAC  22   9   91.9  ...  32.4  30.1   71.7 -11.2   NaN
# 212                     UCF  Amer  23  11  105.9  ...  35.5  32.7   66.9  -3.1   NaN
# 337               UC Irvine    BW  25  18   99.0  ...  32.9  32.9   67.8  -3.7   NaN
# ...

# %% [markdown]
# **Sort the database into the Conferences to see if there are any patterns or visualizations for Conferences.**

# %%
df_conf = df.sort_values('CONF')
print(df_conf)
# Out:
#               TEAM CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 139  Massachusetts  A10  15   8  105.4  ...  32.6  33.8   71.7 -3.5   NaN
# 155       Duquesne  A10  18   9  102.1  ...  29.9  28.4   68.9 -4.1   NaN
# 39             VCU  A10  26  19  104.6  ...  32.9  30.5   70.0  1.3  10.0
# 175       La Salle  A10  24   9  101.9  ...  33.6  32.9   68.8 -8.7   NaN
# 274       Richmond  A10  20  13  109.7  ...  34.3  32.2   69.3 -1.4   NaN
# ..             ...  ...  ..  ..    ...  ...   ...   ...    ...  ...   ...
# 295   Saint Mary's  WCC  23  14   99.2  ...  29.3  34.8   63.6 -0.7   NaN
# 243     Pepperdine  WCC  22  12  107.6  ...  32.5  27.8   71.2 -4.2   NaN
# 159        Pacific  WCC  17   9  102.5  ...  29.8  35.1   66.6 -3.1   NaN
# 3          Gonzaga  WCC  26  26  125.4  ...  36.5  32.5   74.6  8.5   1.0
# 76       San Diego  WCC  14   3   97.7  ...  30.4  38.5   70.2 -6.2   NaN
#
# [347 rows x 22 columns]

# %%
df_conf_best = df_conf.sort_values('W', ascending = False)
print(df_conf_best)
# Out:
#                    TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 346             Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1  -1.1   NaN
# 3               Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 45                Drake   MVC  27  25  111.8  ...  36.6  30.8   66.7   1.5  11.0
# 31       Loyola Chicago   MVC  26  24  108.5  ...  35.7  32.5   63.9   1.7   8.0
# 6               Houston  Amer  26  24  120.6  ...  35.5  28.5   65.0   4.0   2.0
# ..                  ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 73               Denver   Sum  20   2   93.9  ...  34.8  39.3   70.9 -16.8   NaN
# 70                Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 68               Howard  MEAC   5   1   95.8  ...  34.6  33.9   70.8  -3.4   NaN
# 69   South Carolina St.  MEAC  18   1   86.5  ...  31.9  36.1   72.7 -14.7   NaN
# 252         Chicago St.   WAC   9   0   85.0  ...  25.1  39.5   70.5  -5.8   NaN
#
# ...

# %%
df_conf = df.sort_values('W', ascending = False)
print(df_conf)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 346                 Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1  -1.1   NaN
# 3                   Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 45                    Drake   MVC  27  25  111.8  ...  36.6  30.8   66.7   1.5  11.0
# 31           Loyola Chicago   MVC  26  24  108.5  ...  35.7  32.5   63.9   1.7   8.0
# 6                   Houston  Amer  26  24  120.6  ...  35.5  28.5   65.0   4.0   2.0
# ..                      ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 75   Mississippi Valley St.  SWAC  24   2   80.0  ...  32.9  35.8   72.3 -17.5   NaN
# 70                    Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 69       South Carolina St.  MEAC  18   1   86.5  ...  31.9  36.1   72.7 -14.7   NaN
# 68                   Howard  MEAC   5   1   95.8  ...  34.6  33.9   70.8  -3.4   NaN
# ...

# %%
df_win_perc = df['W']/df['G']

# %%
df_games = df.groupby('G')
display(df_games)

# %% [markdown]
# **Grouping and finding values for teams and also win percentages by team**

# %%
df_team = df.sort_values('TEAM')
print(df_conf)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 346                 Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1  -1.1   NaN
# 3                   Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 45                    Drake   MVC  27  25  111.8  ...  36.6  30.8   66.7   1.5  11.0
# 31           Loyola Chicago   MVC  26  24  108.5  ...  35.7  32.5   63.9   1.7   8.0
# 6                   Houston  Amer  26  24  120.6  ...  35.5  28.5   65.0   4.0   2.0
# ..                      ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 75   Mississippi Valley St.  SWAC  24   2   80.0  ...  32.9  35.8   72.3 -17.5   NaN
# 70                    Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 69       South Carolina St.  MEAC  18   1   86.5  ...  31.9  36.1   72.7 -14.7   NaN
# 68                   Howard  MEAC   5   1   95.8  ...  34.6  33.9   70.8  -3.4   NaN
# ...

# %%
fig = px.histogram(df_conf, x='CONF', title='Games won by Conference', nbins=36)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d6124b6e-e500-4695-8f1e-922de3b7c9cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d6124b6e-e500-4695-8f1e-922de3b7c9cd")) {
#                     Plotly.newPlot(
#                         'd6124b6e-e500-4695-8f1e-922de3b7c9cd',
# ...

# %%
fig = px.scatter(df, x='ADJOE', y='W', title='Correlation between Adjusted Offensive Efficiency and Winning Games')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="744f97d8-3716-49d2-a109-9266c88a159a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("744f97d8-3716-49d2-a109-9266c88a159a")) {
#                     Plotly.newPlot(
#                         '744f97d8-3716-49d2-a109-9266c88a159a',
# ...

# %% [markdown]
# **Initial Findings**
# Adjusted Offensive Efficiency and the number of games won seems to have a positive correlation with each other. Definitely not a causal relationship, but could play a role in how the teams won.

# %%
fig = px.scatter(df, x='ADJDE', y='W', title='Correlation between Adjusted Defensive Efficiency and Winning Games')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4c65ca0b-b666-4bf2-9311-36f51f0b9f71" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c65ca0b-b666-4bf2-9311-36f51f0b9f71")) {
#                     Plotly.newPlot(
#                         '4c65ca0b-b666-4bf2-9311-36f51f0b9f71',
# ...

# %% [markdown]
# **Initial Findings**
# On the other hand, it seems that Adjusted Dfensive Efficiency seems to have a negative correlation with winning games. Though not causal, another aspect to take a look at with the ADJOE.

# %%
fig = px.scatter_3d(
    df,
    title='Winning teams by Conference',
    x="CONF",
    y="TEAM",
    z="W",
    color="TEAM",
    template='plotly_dark',
    width=800,
    height=800
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80d0c42d-ec2f-4bc1-9cbc-89462c2cb433" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80d0c42d-ec2f-4bc1-9cbc-89462c2cb433")) {
#                     Plotly.newPlot(
#                         '80d0c42d-ec2f-4bc1-9cbc-89462c2cb433',
# ...

# %% [markdown]
# An interesting way to look at the total number of teams, the conferences they play in and the number of games won. It does look a bit messy for now, so will plan to clean it up or choose a different visualization for the final project.
